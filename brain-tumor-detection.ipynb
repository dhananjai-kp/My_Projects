# %% [markdown]
# ### Installing dependencies for preprocessing of images

# %%
# !pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.3.tar.gz (17 kB)
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.3-py3-none-any.whl size=25850 sha256=41078d2a10010a255336e5733e65de4406cc989ba757fe504193dd209a91e341
#   Stored in directory: /root/.cache/pip/wheels/fc/9c/6d/1826267c72afa51b564c9c6e0f66abc806879338bc593a2270
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.3
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %% [markdown]
# **### Helper Functions

# %%
import numpy as np 
import pandas as pd 
import os
from os import listdir
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import imutils    

from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Conv2D,Input,ZeroPadding2D,BatchNormalization,Flatten,Activation,Dense,MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle #shuffling the data improves the model

# %% [markdown]
# ### Loading Images

# %%
image_dir="../input/brain-mri-images-for-brain-tumor-detection/"

# %% [markdown]
# ### Making directory for augmented images

# %% [markdown]
# **A directory is formed using os.makedirs() function for augmented images(yes/ no). Note- custom directory is obtained in outputs folder.**

# %%
os.makedirs('../output/kaggle/working/augmented-images')
os.makedirs('../output/kaggle/working/augmented-images/yes')
os.makedirs('../output/kaggle/working/augmented-images/no')

# %% [markdown]
# ## Augmentation of images
# **About the data:
# The dataset contains 2 folders: yes and no which contains 253 Brain MRI Images. The folder yes contains 155 Brain MRI Images that are tumorous and no contains 98 Brain MRI Images that are non-tumorous.**

# %%
def augment_data(file_dir, n_generated_samples, save_to_dir):
    data_gen = ImageDataGenerator(rotation_range=10, 
                                  width_shift_range=0.1, 
                                  height_shift_range=0.1, 
                                  shear_range=0.1, 
                                  brightness_range=(0.3, 1.0),
                                  horizontal_flip=True, 
                                  vertical_flip=True, 
                                  fill_mode='nearest'
                                 )

    for filename in listdir(file_dir):
        image = cv2.imread(file_dir + '/' + filename)
        # reshape the image
        image = image.reshape((1,)+image.shape)
        save_prefix = 'aug_' + filename[:-4]
        i=0
        for batch in data_gen.flow(x=image, batch_size=1, save_to_dir=save_to_dir,save_prefix=save_prefix, save_format='jpg'):
                i += 1
                if i > n_generated_samples:
                    break

# %%
augmented_data_path ='../output/kaggle/working/augmented-images/'
# augment data for the examples with label equal to 'yes' representing tumurous examples
augment_data(file_dir=image_dir+'yes',n_generated_samples=6, save_to_dir=augmented_data_path+'yes')
# augment data for the examples with label equal to 'no' representing non-tumurous examples
augment_data(file_dir=image_dir+'no', n_generated_samples=9, save_to_dir=augmented_data_path+'no')

# %% [markdown]
# ## Preprocessing the data
#
# In order to crop the specific part of the image containing tumour,cropping technique via OpenCv is used, the details can be found here.[How to find extreme points in OpenCv?](https://www.pyimagesearch.com/2016/04/11/finding-extreme-points-in-contours-with-opencv/)

# %%
def crop_brain_contour(image, plot=False):
    
    # Convert the image to grayscale, and blur it slightly
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    # extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    
    # crop new image out of the original image using the four extreme points (left, right, top, bottom)
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]            

    if plot:
        plt.figure()
        plt.subplot(1, 2, 1)
        plt.imshow(image)
        plt.tick_params(axis='both', which='both', top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Original Image')
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)
        plt.tick_params(axis='both', which='both',top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Cropped Image')
        plt.show()
    
    return new_image

# %% [markdown]
# ## After applying the cropping function

# %%
ex_img = cv2.imread(image_dir+'yes/Y107.jpg')
ex_crop_img = crop_brain_contour(ex_img, True)

# %%
def load_data(dir_list, image_size):

    # load all images in a directory
    X = []
    y = []
    image_width, image_height = image_size
    
    for directory in dir_list:
        for filename in listdir(directory):
            image = cv2.imread(directory+'/'+filename)
            image = crop_brain_contour(image, plot=False)
            image = cv2.resize(image, dsize=(image_width, image_height), interpolation=cv2.INTER_CUBIC)
            # normalize values
            image = image / 255.
            # convert image to numpy array and append it to X
            X.append(image)
            # append a value of 1 to the target array if the image
            # is in the folder named 'yes', otherwise append 0.
            if directory[-3:] == 'yes':
                y.append([1])
            else:
                y.append([0])
                
    X = np.array(X)
    y = np.array(y)
    
    # Shuffle the data
    X, y = shuffle(X, y)
    
    print(f'Number of examples is: {len(X)}')
    print(f'X shape is: {X.shape}')
    print(f'y shape is: {y.shape}')
    
    return X, y

# %%
augmented_yes =augmented_data_path+'yes'
augmented_no = augmented_data_path+'no'

IMG_WIDTH, IMG_HEIGHT = (240, 240)

X, y = load_data([augmented_yes, augmented_no], (IMG_WIDTH, IMG_HEIGHT))
# Out:
# Number of examples is: 2065
# X shape is: (2065, 240, 240, 3)
# y shape is: (2065, 1)

# %% [markdown]
# ## Visualization of data

# %%
def plot_sample_images(X, y, n=40):
    for label in [0,1]:
        # grab the first n images with the corresponding y values equal to label
        images = X[np.argwhere(y == label)]
        n_images = images[:n]
        
        columns_n = 10
        rows_n = int(n/ columns_n)

        plt.figure(figsize=(10, 8))
        
        i = 1 # current plot        
        for image in n_images:
            plt.subplot(rows_n, columns_n, i)
            plt.imshow(image[0])
            
            # remove ticks
            plt.tick_params(axis='both', which='both', 
                            top=False, bottom=False, left=False, right=False,
                           labelbottom=False, labeltop=False, labelleft=False, labelright=False)
            
            i += 1
        
        label_to_str = lambda label: "Yes" if label == 1 else "No"
        plt.suptitle(f"Brain Tumor: {label_to_str(label)}")
        plt.show()

# %%
plot_sample_images(X, y)

# %%
def split_data(X, y, test_size=0.2):
       
    X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=test_size)
    X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(X, y, test_size=0.3)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
# Out:
# number of training examples = 1445
# number of validation examples = 310
# number of test examples = 310

# %%
def build_model(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    
    X = Conv2D(32, (7, 7), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    
    X = MaxPooling2D((4, 4))(X) 
    X = MaxPooling2D((4, 4))(X) 
    X = Flatten()(X) 
    X = Dense(1, activation='sigmoid')(X) 
    model = Model(inputs = X_input, outputs = X)
    
    return model

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model=build_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 244, 244, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 59, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6273
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x=X_train, y=y_train, batch_size=32, epochs=22, validation_data=(X_val, y_val))
# Out:
# Epoch 1/22
# 46/46 [==============================] - 2s 52ms/step - loss: 0.7475 - accuracy: 0.6471 - val_loss: 0.6613 - val_accuracy: 0.6065
# Epoch 2/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.5090 - accuracy: 0.7675 - val_loss: 0.6169 - val_accuracy: 0.6290
# Epoch 3/22
# 46/46 [==============================] - 2s 37ms/step - loss: 0.3895 - accuracy: 0.8298 - val_loss: 0.5538 - val_accuracy: 0.7742
# Epoch 4/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.4209 - accuracy: 0.8125 - val_loss: 0.6789 - val_accuracy: 0.5645
# Epoch 5/22
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3161 - accuracy: 0.8768 - val_loss: 0.8181 - val_accuracy: 0.5323
# Epoch 6/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.2850 - accuracy: 0.8858 - val_loss: 0.6425 - val_accuracy: 0.6258
# Epoch 7/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.2924 - accuracy: 0.8713 - val_loss: 0.7397 - val_accuracy: 0.6032
# Epoch 8/22
# 46/46 [==============================] - 2s 38ms/step - loss: 0.2966 - accuracy: 0.8699 - val_loss: 0.3653 - val_accuracy: 0.8613
# Epoch 9/22
# 46/46 [==============================] - 2s 38ms/step - loss: 0.2243 - accuracy: 0.9142 - val_loss: 0.4200 - val_accuracy: 0.8258
# Epoch 10/22
# 46/46 [==============================] - 2s 37ms/step - loss: 0.2135 - accuracy: 0.9128 - val_loss: 0.2944 - val_accuracy: 0.8935
# Epoch 11/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1785 - accuracy: 0.9439 - val_loss: 0.3621 - val_accuracy: 0.8516
# Epoch 12/22
# 46/46 [==============================] - 2s 38ms/step - loss: 0.1898 - accuracy: 0.9301 - val_loss: 0.5469 - val_accuracy: 0.7645
# Epoch 13/22
# 46/46 [==============================] - 2s 36ms/step - loss: 0.1774 - accuracy: 0.9446 - val_loss: 0.3375 - val_accuracy: 0.8645
# Epoch 14/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.1598 - accuracy: 0.9384 - val_loss: 0.2660 - val_accuracy: 0.9032
# Epoch 15/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1393 - accuracy: 0.9578 - val_loss: 0.2768 - val_accuracy: 0.8903
# Epoch 16/22
# 46/46 [==============================] - 2s 38ms/step - loss: 0.1436 - accuracy: 0.9446 - val_loss: 0.3008 - val_accuracy: 0.8645
# Epoch 17/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1160 - accuracy: 0.9682 - val_loss: 0.3331 - val_accuracy: 0.8774
# Epoch 18/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1070 - accuracy: 0.9668 - val_loss: 0.4855 - val_accuracy: 0.8161
# Epoch 19/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1106 - accuracy: 0.9661 - val_loss: 0.3532 - val_accuracy: 0.8710
# Epoch 20/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1137 - accuracy: 0.9626 - val_loss: 0.6128 - val_accuracy: 0.7742
# Epoch 21/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0868 - accuracy: 0.9792 - val_loss: 0.4223 - val_accuracy: 0.8097
# Epoch 22/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0738 - accuracy: 0.9855 - val_loss: 0.2583 - val_accuracy: 0.9065

# %%
history = model.history.history

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Plotting of accuracy

# %%
plot_metrics(history)

# %% [markdown]
# #### Adding a drop out layer of 0.5

# %%
from tensorflow.keras.layers import Dropout

# %%
def build_model_1(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    
    X = Conv2D(32, (7, 7), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    X = Dropout(0.5)(X)
    
    X = MaxPooling2D((4, 4))(X) 
    X = MaxPooling2D((4, 4))(X) 
    X = Flatten()(X) 
    X = Dense(1, activation='sigmoid')(X) 
    model_1 = Model(inputs = X_input, outputs = X)
    
    return model_1

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model_1=build_model(IMG_SHAPE)
model_1.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 244, 244, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 59, 59, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_1.fit(x=X_train, y=y_train, batch_size=32, epochs=22, validation_data=(X_val, y_val))
# Out:
# Epoch 1/22
# 46/46 [==============================] - 2s 43ms/step - loss: 0.8963 - accuracy: 0.5862 - val_loss: 0.6527 - val_accuracy: 0.6065
# Epoch 2/22
# 46/46 [==============================] - 2s 37ms/step - loss: 0.5218 - accuracy: 0.7433 - val_loss: 0.6016 - val_accuracy: 0.7226
# Epoch 3/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.4250 - accuracy: 0.8069 - val_loss: 0.5899 - val_accuracy: 0.6516
# Epoch 4/22
# 46/46 [==============================] - 2s 36ms/step - loss: 0.4051 - accuracy: 0.8215 - val_loss: 0.5053 - val_accuracy: 0.8129
# Epoch 5/22
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3608 - accuracy: 0.8464 - val_loss: 0.4553 - val_accuracy: 0.8290
# Epoch 6/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.3141 - accuracy: 0.8740 - val_loss: 0.4365 - val_accuracy: 0.8194
# Epoch 7/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.2783 - accuracy: 0.8907 - val_loss: 0.6736 - val_accuracy: 0.6194
# Epoch 8/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3010 - accuracy: 0.8720 - val_loss: 0.3416 - val_accuracy: 0.8677
# Epoch 9/22
# 46/46 [==============================] - 2s 36ms/step - loss: 0.2472 - accuracy: 0.9114 - val_loss: 0.3694 - val_accuracy: 0.8548
# Epoch 10/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.2096 - accuracy: 0.9308 - val_loss: 0.4984 - val_accuracy: 0.7839
# Epoch 11/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.2040 - accuracy: 0.9211 - val_loss: 0.2838 - val_accuracy: 0.8935
# Epoch 12/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.2002 - accuracy: 0.9218 - val_loss: 0.7293 - val_accuracy: 0.7290
# Epoch 13/22
# 46/46 [==============================] - 2s 34ms/step - loss: 0.1800 - accuracy: 0.9412 - val_loss: 0.3625 - val_accuracy: 0.8161
# Epoch 14/22
# 46/46 [==============================] - 2s 33ms/step - loss: 0.1774 - accuracy: 0.9405 - val_loss: 0.2969 - val_accuracy: 0.8839
# Epoch 15/22
# 46/46 [==============================] - 2s 39ms/step - loss: 0.1902 - accuracy: 0.9239 - val_loss: 1.4523 - val_accuracy: 0.6065
# Epoch 16/22
# 46/46 [==============================] - 2s 37ms/step - loss: 0.2117 - accuracy: 0.9038 - val_loss: 0.3887 - val_accuracy: 0.8516
# Epoch 17/22
# 46/46 [==============================] - 2s 39ms/step - loss: 0.1427 - accuracy: 0.9502 - val_loss: 0.5965 - val_accuracy: 0.7839
# Epoch 18/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1287 - accuracy: 0.9543 - val_loss: 0.3551 - val_accuracy: 0.8323
# Epoch 19/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1261 - accuracy: 0.9550 - val_loss: 0.3594 - val_accuracy: 0.8774
# Epoch 20/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1510 - accuracy: 0.9377 - val_loss: 0.3131 - val_accuracy: 0.8645
# Epoch 21/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1103 - accuracy: 0.9668 - val_loss: 0.3655 - val_accuracy: 0.8774
# Epoch 22/22
# 46/46 [==============================] - 2s 35ms/step - loss: 0.1113 - accuracy: 0.9633 - val_loss: 0.2736 - val_accuracy: 0.8935

# %%
history_1 = model_1.history.history

# %%
### Plotting of accuracy

# %%
plot_metrics(history_1)

# %% [markdown]
# ## Building model with following changes
#     adding a dense layer relu of value to 64
#     Made the drop-out layer to 0.3
#     Epochs to 50

# %%
# added a dense layer relu of value to 64
# changed the drop-out layer to 0.3

# %%
def build_model_2(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    X = Conv2D(32, (7, 7), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    X = Dropout(0.3)(X)
    X = MaxPooling2D((4, 4))(X) 
    X = Flatten()(X) 
    X = Dense(64, activation='relu')(X)
    X = Dense(1, activation='sigmoid')(X) 
    model_2 = Model(inputs = X_input, outputs = X)
    
    return model_2

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model_2=build_model_2(IMG_SHAPE)
model_2.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 244, 244, 3)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation_2 (Activation)    (None, 238, 238, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 59, 59, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 111392)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                7129152
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 7,134,081
# Trainable params: 7,134,017
# Non-trainable params: 64
# _________________________________________________________________

# %%
# changes Epochs to 50
model_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_2.fit(x=X_train, y=y_train, batch_size=32, epochs=50, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 46/46 [==============================] - 2s 52ms/step - loss: 7.4967 - accuracy: 0.5059 - val_loss: 0.6931 - val_accuracy: 0.5065
# Epoch 2/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.6930 - accuracy: 0.5163 - val_loss: 0.6931 - val_accuracy: 0.5065
# Epoch 3/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.6929 - accuracy: 0.5163 - val_loss: 0.6931 - val_accuracy: 0.5065
# Epoch 43/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.6926 - accuracy: 0.5163 - val_loss: 0.6933 - val_accuracy: 0.5065
# Epoch 44/50
# 46/46 [==============================] - 2s 49ms/step - loss: 0.6927 - accuracy: 0.5163 - val_loss: 0.6933 - val_accuracy: 0.5065
# Epoch 45/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.6927 - accuracy: 0.5163 - val_loss: 0.6932 - val_accuracy: 0.5065
# Epoch 46/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.6927 - accuracy: 0.5163 - val_loss: 0.6932 - val_accuracy: 0.5065
# Epoch 47/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.6926 - accuracy: 0.5163 - val_loss: 0.6932 - val_accuracy: 0.5065
# Epoch 48/50
# 46/46 [==============================] - 2s 47ms/step - loss: 0.6927 - accuracy: 0.5163 - val_loss: 0.6932 - val_accuracy: 0.5065
# Epoch 49/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.6926 - accuracy: 0.5163 - val_loss: 0.6932 - val_accuracy: 0.5065
# Epoch 50/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.6927 - accuracy: 0.5163 - val_loss: 0.6932 - val_accuracy: 0.5065

# %%
history_2 = model_1.history.history

# %%
plot_metrics(history_2)

# %%
## conv (3,3)
# Changed the epochs to 30
# dense layer to 59
# Maxpooling to 2,2
# drop out to 0.5

# %%
def build_model_3(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    X = Conv2D(32, (3, 3), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    X = Dropout(0.2)(X)
    X = MaxPooling2D((2, 2))(X)
    
    X = Flatten()(X) 
    X = Dense(59, activation='relu')(X)
    X = Dense(1, activation='sigmoid')(X) 
    model_3 = Model(inputs = X_input, outputs = X)
    
    return model_3

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model_3=build_model_1(IMG_SHAPE)
model_3.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 244, 244, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation_3 (Activation)    (None, 238, 238, 32)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 59, 59, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_3.fit(x=X_train, y=y_train, batch_size=32, epochs=30, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 46/46 [==============================] - 2s 50ms/step - loss: 1.2536 - accuracy: 0.6090 - val_loss: 0.6769 - val_accuracy: 0.5226
# Epoch 2/30
# 46/46 [==============================] - 2s 43ms/step - loss: 0.5931 - accuracy: 0.7301 - val_loss: 0.6481 - val_accuracy: 0.5935
# Epoch 3/30
# Epoch 23/30
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0899 - accuracy: 0.9709 - val_loss: 0.3379 - val_accuracy: 0.8290
# Epoch 24/30
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0797 - accuracy: 0.9737 - val_loss: 0.3595 - val_accuracy: 0.8194
# Epoch 25/30
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0732 - accuracy: 0.9758 - val_loss: 0.3310 - val_accuracy: 0.8290
# Epoch 26/30
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0590 - accuracy: 0.9862 - val_loss: 0.2847 - val_accuracy: 0.8774
# Epoch 27/30
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0530 - accuracy: 0.9848 - val_loss: 0.3909 - val_accuracy: 0.8161
# Epoch 28/30
# 46/46 [==============================] - 2s 41ms/step - loss: 0.2244 - accuracy: 0.9100 - val_loss: 0.3288 - val_accuracy: 0.8516
# Epoch 29/30
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0996 - accuracy: 0.9557 - val_loss: 0.4319 - val_accuracy: 0.7903
# Epoch 30/30
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0543 - accuracy: 0.9862 - val_loss: 0.2816 - val_accuracy: 0.8935

# %%
history_3 = model_3.history.history

# %%
plot_metrics(history_3)

# %% [markdown]
# ## conv (3,3)
# ## Changed the epochs to 30
# ## dense layer to 59
# ## Maxpooling to 2,2
# ## drop out to 0.5
#
# ## adding one more convolution of same layers

# %%
def build_model_4(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    X = Conv2D(32, (3, 3), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    X = Dropout(0.2)(X)
    X = MaxPooling2D((2, 2))(X)
    
    X = ZeroPadding2D((2, 2))(X)
    X = Conv2D(32, (3, 3), strides = (1, 1))(X)
    X = BatchNormalization(axis = 3, name = 'bn1')(X)
    X = Activation('relu')(X)
    X = Dropout(0.2)(X)
    X = MaxPooling2D((2, 2))(X)
    
    X = Flatten()(X) 
    X = Dense(59, activation='relu')(X)
    X = Dense(1, activation='sigmoid')(X) 
    model_4 = Model(inputs = X_input, outputs = X)
    
    return model_4

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model_4=build_model_1(IMG_SHAPE)
model_4.summary()
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 244, 244, 3)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation_4 (Activation)    (None, 238, 238, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 59, 59, 32)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_4.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_4.fit(x=X_train, y=y_train, batch_size=32, epochs=30, validation_data=(X_val, y_val))

# %%
history_4 = model_4.history.history

# %%
plot_metrics(history_4)
